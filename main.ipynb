# %%
from gnews import GNews

# %%
google_news = GNews()

nepal_news = google_news.get_news('nepal')

# %%
print(nepal_news[0])
# Out:
# {'title': 'Nepal asks Russia to send back Nepalis recruited to fight in Ukraine and the bodies of those killed - The Associated Press', 'description': 'Nepal asks Russia to send back Nepalis recruited to fight in Ukraine and the bodies of those killed  The Associated Press', 'published date': 'Thu, 25 Jan 2024 11:17:00 GMT', 'url': 'https://news.google.com/rss/articles/CBMiXWh0dHBzOi8vYXBuZXdzLmNvbS9hcnRpY2xlL25lcGFsLWZpZ2h0ZXJzLXJ1c3NpYS11a3JhaW5lLXdhci1lNTdhNDU2NDU2NjZkMDI2NTFmNmVmZWQ0ZTNmMjFhZdIBAA?oc=5&hl=en-IN&gl=IN&ceid=IN:en', 'publisher': {'href': 'https://apnews.com', 'title': 'The Associated Press'}}

# %%
len(nepal_news)
# Out:
# 99

# %%
from datetime import datetime

# Assuming nepal_news is a list of dictionaries
for news in nepal_news:
    # Parse date string to datetime object
    news['published date'] = datetime.strptime(news['published date'], '%a, %d %b %Y %H:%M:%S %Z')

# Sort the news by date
nepal_news.sort(key=lambda x: x['published date'])

# %%
nepal_news[98]
# Out:
# {'title': "Echoes From The Height: The Enigma Of Nepal's Mustang Caves - News18",
#  'description': "Echoes From The Height: The Enigma Of Nepal's Mustang Caves  News18",
#  'published date': datetime.datetime(2024, 1, 27, 14, 19, 1),
#  'url': 'https://news.google.?oc=5&hl=en-IN&gl=IN&ceid=IN:en',
#  'publisher': {'href': 'https://www.news18.com', 'title': 'News18'}}

# %%
import pandas as pd

# Assuming nepal_news is your list of dictionaries
df = pd.json_normalize(nepal_news)

# If 'published date' is not recognized, try using 'published_date' instead

# %%
df.head()
# Out:
#                                                title  \
# 0  The Met to return two ancient artifacts to Nep...
# 1  Nepal says 10 nationals killed in Israel after...
# 2  Student Project for Peace Focuses on Youth in ...
# 3  Nepal Water Initiative flourishes with multidi...
# 4  UN chief visits tallest mountains in Nepal and...
#
#                                          description      published date  \
# 0  The Met to return two ancient artifacts to Nep... 2023-10-06 07:00:00
# 1  Nepal says 10 nationals killed in Israel after... 2023-10-09 07:00:00
# 2  Student Project for Peace Focuses on Youth in ... 2023-10-18 07:00:00
# 3  Nepal Water Initiative flourishes with multidi... 2023-10-23 07:00:00
# 4  UN chief visits tallest mountains in Nepal and... 2023-10-31 07:00:00
#
#                                                  url  \
# 0  https://news.google.com/rss/articles/CBMiZmh0d...
# 1  https://news.google.com/rss/articles/CBMiYmh0d...
# 2  https://news.google.com/rss/articles/CBMiU2h0d...
# 3  https://news.google.com/rss/articles/CBMicGh0d...
# 4  https://news.google.com/rss/articles/CBMiZWh0d...
#
#                publisher.href                     publisher.title
# 0        https://www.icij.org                            ICIJ.org
# 1     https://www.reuters.com                             Reuters
# 2  https://www.middlebury.edu  Middlebury College News and Events
# 3         https://news.wm.edu                      William & Mary
# 4          https://apnews.com                The Associated Press

# %%
max_length_of_news = 30
df['full_article'] = df.tail(max_length_of_news)['url'].apply(google_news.get_full_article).apply(lambda x: x.text)

# %%
df['images'] = df.tail(max_length_of_news)['url'].apply(google_news.get_full_article).apply(lambda x: x.images)

# 75  {https://www.hindustantimes.com/static-content...
# 76  {https://images.icc-cricket.com/image/private/...
# 77  {https://www.facebook.com/tr?ev=6024262178418&...
# 78  {https://wassets.hscicdn.com/static/images/laz...
# 79  {https://images.icc-cricket.com/image/upload/t...
# 80  {......
# 81  {https://www.hindustantimes.com/static-content...
# 82  {https://sb.scorecardresearch.com/p?c1=2&c2=60...
# 83  {https://i0.wp.com/www.directrelief.org/wp-con...
# 84  {https://jcss-cdn.kathmandupost.com/assets/ima...
# 85  {https://www.indiandefencereview.com/wp-conten...
# 86  {https://news.google.com/img/social-tw.svg, ht...
# 87  {https://jcss-cdn.kathmandupost.com/assets/ima...
# 88  {https://jcss-cdn.kathmandupost.com/assets/ima...
# 89  {https://myrepublica.nagariknetwork.com/upload...
# 90  {https://myrepublica.nagariknetwork.com/upload...
# 91  {https://www.firstpost.com//static/images/1490...
# 92  {https://myrepublica.nagariknetwork.com/upload...
# 93  {https://myrepublica.nagariknetwork.com/upload...
# 94  {https://myrepublica.nagariknetwork.com/upload...
# 95  {https://assets-cdn.kathmandupost.com/uploads/...
# 96  {https://myrepublica.nagariknetwork.com/upload...
# 97  {https://i0.wp.com/www.mercurynews.com/wp-cont...
# 98  {https://images.news18.com/ibnlive/uploads/202...

# %%
from googletranslate import translate

# %%
df['full_article'] = df.tail(max_length_of_news)['full_article'].apply(lambda x: ''.join(i for i in str(x) if ord(i) < 0x10000))

print('removed non-ascii characters')
# Out:
# removed non-ascii characters

# %%
import requests
import json

def translate_text(x):
    try:
        translation_result = translate(x, dest='mai', src='en')
        return translation_result
    except requests.exceptions.RequestException as e:
        print(f"Error making translation request: {e}")
        return None  # Handle the error gracefully, you can modify this based on your needs
    except json.decoder.JSONDecodeError as e:
        print(f"Error decoding JSON response: {e}")
        return None  # Handle the error gracefully, you can modify this based on your needs

# Assuming 'max_length_of_news' is defined
df['translated'] = df.tail(max_length_of_news)['full_article'].apply(translate_text)
# Out:
# Error making translation request: Expecting value: line 1 column 1 (char 0)

# %%
df['translated'] = df.tail(max_length_of_news)['full_article'].apply(lambda x: translate(x, dest='mai', src='en'))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.python/current/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/.python/current/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/.python/current/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/.python/current/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df['translated'] = df.tail(max_length_of_news)['full_article'].apply(lambda x: translate(x, dest='mai', src='en'))
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1209, in SeriesApply.apply(self)
#    1206     return self.apply_compat()
#    1208 # self.func is Callable
# -> 1209 return self.apply_standard()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1289, in SeriesApply.apply_standard(self)
#    1283 # row-wise access
#    1284 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1285 # we need to give `na_action="ignore"` for categorical data.
#    1286 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1287 #  Categorical (GH51645).
#    1288 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289 mapped = obj._map_values(
#    1290     mapper=curried, na_action=action, convert=self.convert_dtype
#    1291 )
#    1293 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1294     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1295     #  See also GH#25959 regarding EA support
#    1296     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# Cell In[15], line 1, in <lambda>(x)
# ----> 1 df['translated'] = df.tail(max_length_of_news)['full_article'].apply(lambda x: translate(x, dest='mai', src='en'))
#
# File ~/.python/current/lib/python3.10/site-packages/googletranslate/__init__.py:184, in translate(text, dest, src)
#     179 def translate(
#     180     text,
#     181     dest,
#     182     src="auto",
#     183 ):
# --> 184     return Translator(dest, src).translate(text)
#
# File ~/.python/current/lib/python3.10/site-packages/googletranslate/__init__.py:286, in Translator.translate(self, text)
#     284 r = self._call(url, **params)
#     285 logger.debug('response: %s => %s' % (r, r.text))
# --> 286 raw = r.json()
#     287 self._last_data = raw
#     289 if not raw:
#
# File ~/.python/current/lib/python3.10/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df.tail(max_length_of_news)
# Out:
#                                                 title  \
# 69  'Friendly people of India..': Nepal PM extends...
# 70  Nepal Vs Afghanistan, ICC U-19 Cricket World C...
# 71  Cricket photo index - Afghan U19 vs Nepal U19,...
# 72  On Nepal Research Trip, Graduate Students Stri...
# 73  Persons with Disabilities Combating Mis/Disinf...
# 74  Mountain Heart Nepal Provides Mobile Clinics i...
# 75  Afghanistan Under-19 vs Nepal Under-19 Live Sc...
# 76  Nepal bowler guilty of breaching ICC Code of C...
# 77  Nepal wants single biometric database for ID c...
# 78  ICC Men's Under-19 World Cup - Nepal beat Afgh...
# 79  Nepal, West Indies win nailbiters; Bangladesh ...
# 80  Afghanistan vs Nepal, U-19 World Cup 2024 High...
# 81  U-19 Cricket World Cup: Nepal, West Indies win...
# 82  Maidstone’s Bivesh Gurung: ‘In Nepal I was the...
# 83  Operational Update: Medical Support for Ukrain...
# 84  Chand fifer, Khanal fifty take Nepal to Super ...
# 85  Diplomatic Success: Unraveling the Key Agreeme...
# 86  The sacred female singers of Nepal - Nepali times
# 87  Report reveals 65 percent of patients in Nepal...
# 88  Chinese politicians meeting Nepali leaders - T...
# 89    Unleashing Nepal's Digital Future - Myrepublica
# 90  AmCham Nepal hosts 6th Member Learning Series ...
# 91  ICC Under-19 World Cup: Nepal edge Afghanistan...
# 92  Red Corner Notice issued against fugitive Dev ...
# 93  Nepal Calendar Determination Committee approve...
# 94  FNCCI Prez urges NRNs in Qatar to invest in Ne...
# 95  'Nepali Congress in community' campaign launch...
# 96  Tamang elected President of Chefs Association ...
# 97  Antioch mom works to help ill Nepali man get l...
# 98  Echoes From The Height: The Enigma Of Nepal's ...
#
#                                           description      published date  \
# 69  'Friendly people of India..': Nepal PM extends... 2024-01-26 07:31:00
# 70  Nepal Vs Afghanistan, ICC U-19 Cricket World C... 2024-01-26 08:02:14
# 71  Cricket photo index - Afghan U19 vs Nepal U19,... 2024-01-26 09:33:48
# 72  On Nepal Research Trip, Graduate Students Stri... 2024-01-26 10:30:00
# 73  Persons with Disabilities Combating Mis/Disinf... 2024-01-26 11:38:13
# 87  Report reveals 65 percent of patients in Nepal...
# 88  Chinese politicians meeting Nepali leaders\n\n...
# 89  FDI in ICTs play vital role in general and dat...
# 90  KATHMANDU, Jan 27: The American Chamber of Com...
# 91  Nepal cricket team defeated Afghanistan in a t...
# 92  GALKOT, Jan 27: The Interpol Division of Polic...
# 93  The approved calendar will be available in the...
# 94  KATHMANDU, Jan 27: Chandra Prasad Dhakal, Pres...
# 95  ‘Nepali Congress in community’ campaign launch...
# 96  KATHMANDU, Jan 27: Resham Kumar Lama Tamang ha...
# 97  ANTIOCH – A new kidney is all that stands betw...
# 98  Nestled high in the breathtaking Mustang distr...
#
#                                                images  \
# 69  {https://static.toiimg.com/thumb/msid-10716531...
# 70  {https://imgnew.outlookindia.com/uploadimage/l...
# 71  {https://www.espncricinfo.com/static/images/es...
# 72  {https://umd-today.transforms.svdcdn.com/produ...
# 73  {https://www.ibe.unesco.org/sites/default/file...
# 74  {https://www.medangel.org/wp-content/uploads/2...
# 75  {https://www.hindustantimes.com/static-content...
# 76  {https://images.icc-cricket.com/image/private/...
# 77  {https://www.facebook.com/tr?ev=6024262178418&...
# 78  {https://wassets.hscicdn.com/static/images/laz...
# 79  {https://images.icc-cricket.com/image/upload/t...
# 80  {......
# 81  {https://www.hindustantimes.com/static-content...
# 82  {https://sb.scorecardresearch.com/p?c1=2&c2=60...
# 83  {https://i0.wp.com/www.directrelief.org/wp-con...
# 84  {https://jcss-cdn.kathmandupost.com/assets/ima...
# 85  {https://www.indiandefencereview.com/wp-conten...
# 86  {https://news.google.com/img/social-tw.svg, ht...
# 87  {https://jcss-cdn.kathmandupost.com/assets/ima...
# 88  {https://jcss-cdn.kathmandupost.com/assets/ima...
# 89  {https://myrepublica.nagariknetwork.com/upload...
# 90  {https://myrepublica.nagariknetwork.com/upload...
# 91  {https://www.firstpost.com//static/images/1490...
# 92  {https://myrepublica.nagariknetwork.com/upload...
# 93  {https://myrepublica.nagariknetwork.com/upload...
# 94  {https://myrepublica.nagariknetwork.com/upload...
# 95  {https://assets-cdn.kathmandupost.com/uploads/...
# 96  {https://myrepublica.nagariknetwork.com/upload...
# 97  {https://i0.wp.com/www.mercurynews.com/wp-cont...
# 98  {https://images.news18.com/ibnlive/uploads/202...
#
#                                            translated
# 69  काठमांडू : नेपाल के प्रधानमंत्री पुष्पा कमल दा...
# 70  नेपाल न॑ शुक्रवार क॑ दक्षिण अफ्रीका केरऽ पूर्व...
# 71  नेपाल थ्रिलर में अफगानिस्तान के हरा देलक;एम्हर...
# 72  दुनिया के छत पर सेहो जलवायु परिवर्तन बर्फ के प...
# 73  पत्रकार बनला के बावजूद टिकरम के जे खबरि के संव...
# 74  माउंटेन हार्ट नेपाल नेपाल में मोबाइल क्लिनिक उ...
# 75  अफगानिस्तान अंडर-19 बनाम नेपाल अंडर-19 हाइलाइट...
# 76  ई घटना 24 जनवरी क॑ पूर्वी लंदन म॑ नेपाल आरू पा...
# 77  नेपाली सरकारी अधिकारीक कें घोषणा छै कि पासपोर्...
# 78  नेपाल के विभिन्न चरण में बैग में लागल बुझाइत छ...
# 79  स्कोरकार्ड टॉस : अफगानिस्तान न॑ नुमान शाह केरऽ...
# 80  अफगानिस्तान प॑ एक विकेट जीत दर्ज करै के बाद एए...
# 81  नेपाल न॑ अफगानिस्तान के खिलाफ एक विकेट स॑ एक ए...
# 82  बैरो क॑ हराबै के बाद एफए कप केरऽ तेसरऽ दौर म॑ ...
# 83  परिचालन अपडेट: यूक्रेन, नेपाल, आरू माउई केरऽ च...
# 84  दिल कुमार एले मगर फुटबॉल, क्रिकेट आरू खेल विशे...
# 85  भारतीय विदेश मंत्री एस जयशंकर न॑ 4 जनवरी, 2023...
# 86                                               None
# 87  रिपोर्ट मे पता चलल अछि जे नेपाल मे 65 प्रतिशत ...
# 88  नेपाली नेता सब के चीनी कम्युनिस्ट पार्टी के प्...
# 89  आईसीटीएस मे एफडीआई सामान्य आ डाटा सेंटर आ क्ला...
# 90  काठमांडू, 27 जनवरी : नेपाल म॑ अमेरिकी-निवेशित ...
# 91  नेपाल क्रिकेट टीम न॑ शुक्रवार क॑ ईस्ट लंदन म॑ ...
# 92  गलकोट, 27 जनवरी : बगलुंग केरऽ डहोरपाटन नगरपालि...
# 93  अनुमोदित कैलेंडर 29 जनवरी स॑ बाजार म॑ उपलब्ध ह...
# 94  काठमांडू, 27 जनवरी : नेपाल केरऽ गैर-निवासी नेप...
# 95  &#39;नेपाली कांग्रेस इन कम्युनिटी&#39; अभियान ...
# 96  काठमांडू, २७ जनवरी : रेशम कुमार लामा तमांग नेप...
# 97  एन्टिओक – गोविन्द रेग्मी आरू अंतहीन प्रतीत होय...
# 98  नेपाल केरऽ लुभावना मस्टैंग जिला म॑ ऊँचऽ बसलऽ ग...

# %%
df.tail(max_length_of_news).to_csv('today_news.csv', index=False)

# %%
main_df = pd.read_csv('filename.csv')
main_df.head()
# Out:
#                                                title  \
# 0  Nepal: Janakpur celebrates Ram Temple Pran Pra...
# 1  From US To Nepal, Indian Community Celebrates ...
# 2  Nepal Red Cross Society Climate and Environmen...
# 3  Nepal Red Cross Society Strategic Framework fo...
# 4  In Nepal, 2.5 Lakh Diya Lit Up To Celebrate Ra...
#
#                                          description       published date  \
# 0  Nepal: Janakpur celebrates Ram Temple Pran Pra...  2024-01-22 13:52:07
# 1  From US To Nepal, Indian Community Celebrates ...  2024-01-22 14:14:29
# 2  Nepal Red Cross Society Climate and Environmen...  2024-01-23 00:53:10
# 3  Nepal Red Cross Society Strategic Framework fo...  2024-01-23 00:59:34
# 4  In Nepal, 2.5 Lakh Diya Lit Up To Celebrate Ra...  2024-01-23 05:33:49
#
#                                                  url  \
# 0  https://news.google.com/rss/articles/CBMilQFod...
# 1  https://news.google.com/rss/articles/CBMifmh0d...
# 2  https://news.google.com/rss/articles/CBMiXmh0d...
# 3  https://news.google.com/rss/articles/CBMidGh0d...
# 4  https://news.google.com/rss/articles/CBMiY2h0d...
#
#                 publisher.href     publisher.title  \
# 0  https://m.economictimes.com  The Economic Times
# 1         https://www.ndtv.com                NDTV
# 2        https://reliefweb.int           ReliefWeb
# 3        https://reliefweb.int           ReliefWeb
# 4         https://www.ndtv.com                NDTV
#
#                                         full_article  \
# 0  The city of Janakpur in Nepal celebrated 'Deep...
# 1  Indian diaspora at Times Square to celebrate t...
# 2  ABOUT THE NEPAL RED CROSS SOCIETY\n\nNepal Red...
# 3  Climate & Environment Context\n\nNepal is amon...
# 4  Janakpur lit up with diyas to mark Ram Temple'...
#
#                                               images  \
# 0  {'https://img.etimg.com/photo/msid-76931895,qu...
# 1  {'https://alerts.ndtv.com/images/web.png', 'ht...
# 2  {'https://news.google.com/themes/custom/common...
# 3  {'https://news.google.com/themes/custom/common...
# 4  {'https://c.ndtvimg.com/2024-01/2pjac238_cm-mo...
#
#                                           translated
# 0  नेपाल केरऽ जनकपुर शहर न॑ ‘दीपोटसाव’ केरऽ मनाबै...
# 1  समय चौक पर भारतीय प्रवासी अयोध्या के राम मंदिर...
# 2  नेपाल रेड क्रॉस सोसाइटी के बारे में नेपाल रेड ...
# 3  जलवायु आरू पर्यावरण संदर्भ नेपाल जलवायु परिवर्...
# 4  जनकपुर अयोध्या में राम मंदिर के &#39;प्राणपत्र...

# %%
len(main_df)
# Out:
# 188

# %%
merged_df = pd.concat([main_df, df.tail(max_length_of_news)]).drop_duplicates(subset=['title']).reset_index(drop=True)

# %%
merged_df.to_csv('filename.csv', index=False)

# %% [markdown]
# # translated

# %%
! pip3 install git+https://github.com/ultrafunkamsterdam/googletranslate
# Out:
# Collecting git+https://github.com/ultrafunkamsterdam/googletranslate
#   Cloning https://github.com/ultrafunkamsterdam/googletranslate to /tmp/pip-req-build-ty34w0i3
#   Running command git clone --filter=blob:none --quiet https://github.com/ultrafunkamsterdam/googletranslate /tmp/pip-req-build-ty34w0i3
#   Resolved https://github.com/ultrafunkamsterdam/googletranslate to commit 1ba75c2d336ea6f6da6b87490d061e0caea9d128
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: googletranslate
#   Building wheel for googletranslate (pyproject.toml) ... done
#   Created wheel for googletranslate: filename=googletranslate-2.2-py3-none-any.whl size=5242 sha256=317077abebfc110bd9ec72eb34b0e7c735cc9c77d75d3d9645cb06540e90894d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q_mxpc40/wheels/97/6b/c5/4f0aed73dd1a5a4168bed70362ee174d515dba6ac3f4cd177a
# Successfully built googletranslate
# Installing collected packages: googletranslate
# Successfully installed googletranslate-2.2

# %%
from googletranslate import translate


translate(merged_df.full_article[0], dest='mai',  src='en' )
# Out:
# 'नेपाल केरऽ जनकपुर शहर न॑ ‘दीपोटसाव’ केरऽ मनाबै छेलै, जेकरा म॑ राम मंदिर प्राण प्रतिश्चा समारोह केरऽ पूरा होय के संकेत छै ।राम मंदिर प्रैण प्रतिथ्था समारोह हिन्दू धर्म केरऽ एगो महत्वपूर्ण घटना छेकै, कैन्हेंकि एकरा म॑ श्री राम केरऽ मूर्ति आरू मंदिर म॑ हुनकऽ पत्नी सीता केरऽ पवित्रीकरण शामिल छै ।'

# %%
merged_df['full_article'] = merged_df['full_article'].apply(lambda x: ''.join(i for i in str(x) if ord(i) < 0x10000))

print('removed non-ascii characters')
# Out:
# removed non-ascii characters

# %%
merged_df['translated'] = merged_df['full_article'].apply(lambda x: translate(x, dest='mai', src='en'))

# %%
merged_df.head()
# Out:
#                                                title  \
# 0  Nepal: Janakpur celebrates Ram Temple Pran Pra...
# 1  From US To Nepal, Indian Community Celebrates ...
# 2  Nepal Red Cross Society Climate and Environmen...
# 3  Nepal Red Cross Society Strategic Framework fo...
# 4  In Nepal, 2.5 Lakh Diya Lit Up To Celebrate Ra...
#
#                                          description       published date  \
# 0  Nepal: Janakpur celebrates Ram Temple Pran Pra...  2024-01-22 13:52:07
# 1  From US To Nepal, Indian Community Celebrates ...  2024-01-22 14:14:29
# 2  Nepal Red Cross Society Climate and Environmen...  2024-01-23 00:53:10
# 3  Nepal Red Cross Society Strategic Framework fo...  2024-01-23 00:59:34
# 4  In Nepal, 2.5 Lakh Diya Lit Up To Celebrate Ra...  2024-01-23 05:33:49
#
#                                                  url  \
# 0  https://news.google.com/rss/articles/CBMilQFod...
# 1  https://news.google.com/rss/articles/CBMifmh0d...
# 2  https://news.google.com/rss/articles/CBMiXmh0d...
# 3  https://news.google.com/rss/articles/CBMidGh0d...
# 4  https://news.google.com/rss/articles/CBMiY2h0d...
#
#                 publisher.href     publisher.title  \
# 0  https://m.economictimes.com  The Economic Times
# 1         https://www.ndtv.com                NDTV
# 2        https://reliefweb.int           ReliefWeb
# 3        https://reliefweb.int           ReliefWeb
# 4         https://www.ndtv.com                NDTV
#
#                                         full_article  \
# 0  The city of Janakpur in Nepal celebrated 'Deep...
# 1  Indian diaspora at Times Square to celebrate t...
# 2  ABOUT THE NEPAL RED CROSS SOCIETY\n\nNepal Red...
# 3  Climate & Environment Context\n\nNepal is amon...
# 4  Janakpur lit up with diyas to mark Ram Temple'...
#
#                                               images  \
# 0  {'https://img.etimg.com/photo/msid-76931895,qu...
# 1  {'https://alerts.ndtv.com/images/web.png', 'ht...
# 2  {'https://news.google.com/themes/custom/common...
# 3  {'https://news.google.com/themes/custom/common...
# 4  {'https://c.ndtvimg.com/2024-01/2pjac238_cm-mo...
#
#                                           translated
# 0  नेपाल केरऽ जनकपुर शहर न॑ ‘दीपोटसाव’ केरऽ मनाबै...
# 1  समय चौक पर भारतीय प्रवासी अयोध्या के राम मंदिर...
# 2  नेपाल रेड क्रॉस सोसाइटी के बारे में नेपाल रेड ...
# 3  जलवायु आरू पर्यावरण संदर्भ नेपाल जलवायु परिवर्...
# 4  जनकपुर अयोध्या में राम मंदिर के &#39;प्राणपत्र...

# %% [markdown]
# # model based classification

# %%
import pandas as pd

# %%
df = pd.read_csv('filename.csv')
df.head()
# Out:
#                                                title  \
# 0  Nepal: Janakpur celebrates Ram Temple Pran Pra...
# 1  From US To Nepal, Indian Community Celebrates ...
# 2  Nepal Red Cross Society Climate and Environmen...
# 3  Nepal Red Cross Society Strategic Framework fo...
# 4  In Nepal, 2.5 Lakh Diya Lit Up To Celebrate Ra...
#
#                                          description       published date  \
# 0  Nepal: Janakpur celebrates Ram Temple Pran Pra...  2024-01-22 13:52:07
# 1  From US To Nepal, Indian Community Celebrates ...  2024-01-22 14:14:29
# 2  Nepal Red Cross Society Climate and Environmen...  2024-01-23 00:53:10
# 3  Nepal Red Cross Society Strategic Framework fo...  2024-01-23 00:59:34
# 4  In Nepal, 2.5 Lakh Diya Lit Up To Celebrate Ra...  2024-01-23 05:33:49
#
#                                                  url  \
# 0  https://news.google.com/rss/articles/CBMilQFod...
# 1  https://news.google.com/rss/articles/CBMifmh0d...
# 2  https://news.google.com/rss/articles/CBMiXmh0d...
# 3  https://news.google.com/rss/articles/CBMidGh0d...
# 4  https://news.google.com/rss/articles/CBMiY2h0d...
#
#                 publisher.href     publisher.title  \
# 0  https://m.economictimes.com  The Economic Times
# 1         https://www.ndtv.com                NDTV
# 2        https://reliefweb.int           ReliefWeb
# 3        https://reliefweb.int           ReliefWeb
# 4         https://www.ndtv.com                NDTV
#
#                                         full_article  \
# 0  The city of Janakpur in Nepal celebrated 'Deep...
# 1  Indian diaspora at Times Square to celebrate t...
# 2  ABOUT THE NEPAL RED CROSS SOCIETY\n\nNepal Red...
# 3  Climate & Environment Context\n\nNepal is amon...
# 4  Janakpur lit up with diyas to mark Ram Temple'...
#
#                                               images  \
# 0  {'https://img.etimg.com/photo/msid-76931895,qu...
# 1  {'https://alerts.ndtv.com/images/web.png', 'ht...
# 2  {'https://news.google.com/themes/custom/common...
# 3  {'https://news.google.com/themes/custom/common...
# 4  {'https://c.ndtvimg.com/2024-01/2pjac238_cm-mo...
#
#                                           translated
# 0  नेपाल केरऽ जनकपुर शहर न॑ ‘दीपोटसाव’ केरऽ मनाबै...
# 1  समय चौक पर भारतीय प्रवासी अयोध्या के राम मंदिर...
# 2  नेपाल रेड क्रॉस सोसाइटी के बारे में नेपाल रेड ...
# 3  जलवायु आरू पर्यावरण संदर्भ नेपाल जलवायु परिवर्...
# 4  जनकपुर अयोध्या में राम मंदिर के &#39;प्राणपत्र...

# %%
df.describe()
# Out:
#                                                     title  \
# count                                                 123
# unique                                                123
# top     Nepal: Janakpur celebrates Ram Temple Pran Pra...
# freq                                                    1
#
#                                               description  \
# count                                                 123
# unique                                                123
# top     Nepal: Janakpur celebrates Ram Temple Pran Pra...
# freq                                                    1
#
#              published date  \
# count                   123
# unique                  118
# top     2024-01-24 15:57:00
# freq                      2
#
#                                                       url  \
# count                                                 123
# unique                                                119
# top     https://news.google.com/rss/articles/CBMihwFod...
# freq                                                    3
#
#                                 publisher.href publisher.title  \
# count                                      123             123
# unique                                      63              62
# top     https://myrepublica.nagariknetwork.com     Myrepublica
# freq                                        14              14
#
#                                              full_article  \
# count                                                  99
# unique                                                 94
# top     Nepal U-19 vs Pakistan U-19 Live Score: Nepal ...
# freq                                                    2
#
#                                                    images translated
# count                                                 106        104
# unique                                                106         95
# top     {'https://img.etimg.com/photo/msid-76931895,qu...  नान 2019।
# freq                                                    1          5

# %%
# import transformers for bertclassifier
import torch
import transformers
from transformers import BertTokenizer, AutoTokenizer, BertModel, BertConfig, AutoModel

import torch.nn as nn

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
# Set your Hugging Face API key
HUGGING_FACE_API_KEY = "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"

from huggingface_hub import login, logout

login()  # displays a widget in a notebook, a prompt in terminal otherwise

login(HUGGING_FACE_API_KEY) # non-blocking login
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /home/codespace/.cache/huggingface/token
# Login successful

# %%
tokenizer = AutoTokenizer.from_pretrained('rockerritesh/maiBERT_TF')
# Out:
# tokenizer_config.json:   0%|          | 0.00/390 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/3.16M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
! wget https://huggingface.co/rockerritesh/maithili_classification_model/resolve/main/maibert.bin?download=true
# Out:
# --2024-01-26 14:12:39--  https://huggingface.co/rockerritesh/maithili_classification_model/resolve/main/maibert.bin?download=true
# Resolving huggingface.co (huggingface.co)... 18.172.78.100, 18.172.78.84, 18.172.78.94, ...
# Connecting to huggingface.co (huggingface.co)|18.172.78.100|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
#
# Username/Password Authentication Failed.

# %%
from huggingface_hub import hf_hub_download

hf_hub_download(
    repo_id="rockerritesh/maithili_classification_model", filename="maibert.bin"
)
# Out:
# maibert.bin:   0%|          | 0.00/950M [00:00<?, ?B/s]
# '/home/codespace/.cache/huggingface/hub/models--rockerritesh--maithili_classification_model/snapshots/dccb02b7f0025ff44b04191fbe94b0d5006b5885/maibert.bin'

# %%
# Creating the customized model, by adding a drop out and a dense layer on top of distil bert to get the final output for the model.

class BERTClass(torch.nn.Module):
    def __init__(self):
        super(BERTClass, self).__init__()
        self.roberta = AutoModel.from_pretrained('rockerritesh/maiBERT_TF', from_tf = True)
        self.l2 = torch.nn.Dropout(0.5)
        self.fc = torch.nn.Linear(768,10)

    def forward(self, ids, mask, token_type_ids):
        _, features = self.roberta(ids, attention_mask = mask, token_type_ids = token_type_ids, return_dict=False)
        output_2 = self.l2(features)
        output = self.fc(output_2)
        return output


# Load the saved state dictionary
model_state_dict_path = '/home/codespace/.cache/huggingface/hub/models--rockerritesh--maithili_classification_model/snapshots/dccb02b7f0025ff44b04191fbe94b0d5006b5885/maibert.bin'
model_state_dict = torch.load(model_state_dict_path,map_location=torch.device('cpu'))

# Create an instance of your model
model = BERTClass()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Load the state dictionary into the model
model.load_state_dict(model_state_dict)

# %% [markdown]
# # streamlit

# %%
! pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.30.0-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from streamlit) (8.1.7)
# Collecting importlib-metadata<8,>=1.4 (from streamlit)
#   Downloading importlib_metadata-7.0.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy<2,>=1.19.3 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (1.26.3)
# Requirement already satisfied: packaging<24,>=16.8 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (10.2.0)
# Collecting protobuf<5,>=3.20 (from streamlit)
#   Downloading protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting pyarrow>=6.0 (from streamlit)
#   Downloading pyarrow-15.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (2.8.2)
# Collecting requests<3,>=2.27 (from streamlit)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (8.2.3)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (4.9.0)
# Collecting tzlocal<6,>=1.1 (from streamlit)
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting validators<1,>=0.2 (from streamlit)
#   Downloading validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (3.1.41)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 11.3 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (6.4)
# Collecting watchdog>=2.1.5 (from streamlit)
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /home/codespace/.local/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (4.20.0)
# Collecting toolz (from altair<6,>=4.0->streamlit)
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Collecting zipp>=0.5 (from importlib-metadata<8,>=1.4->streamlit)
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2023.11.17)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit) (2.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.16.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading streamlit-1.30.0-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 31.1 MB/s eta 0:00:0000:0100:01m
# Downloading altair-5.2.0-py3-none-any.whl (996 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 996.9/996.9 kB 20.8 MB/s eta 0:00:0000:01
# Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Downloading protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 8.5 MB/s eta 0:00:00
# Downloading pyarrow-15.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 20.0 MB/s eta 0:00:0000:0100:01
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 1.8 MB/s eta 0:00:00
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 7.2 MB/s eta 0:00:00
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 2.6 MB/s eta 0:00:00
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: zipp, watchdog, validators, tzlocal, toolz, toml, requests, pyarrow, protobuf, mdurl, cachetools, blinker, pydeck, markdown-it-py, importlib-metadata, rich, altair, streamlit
#   Attempting uninstall: requests
#     Found existing installation: requests 2.26.0
#     Uninstalling requests-2.26.0:
#       Successfully uninstalled requests-2.26.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gnews 0.3.6 requires requests==2.26.0, but you have requests 2.31.0 which is incompatible.
# Successfully installed altair-5.2.0 blinker-1.7.0 cachetools-5.3.2 importlib-metadata-7.0.1 markdown-it-py-3.0.0 mdurl-0.1.2 protobuf-4.25.2 pyarrow-15.0.0 pydeck-0.8.1b0 requests-2.31.0 rich-13.7.0 streamlit-1.30.0 toml-0.10.2 toolz-0.12.1 tzlocal-5.2 validators-0.22.0 watchdog-3.0.0 zipp-3.17.0
